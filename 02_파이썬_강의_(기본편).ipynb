# %% [markdown]
# <a href="https://colab.research.google.com/github/sunjinnn/Python-Education-2026/blob/main/02_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B0%95%EC%9D%98_(%EA%B8%B0%EB%B3%B8%ED%8E%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#퀴즈 3
#사이트별로 비밀번호를 만들어주는 프로그램 생성
#규칙1: http:// 부분은 제외 => naver.com
#규칙2: 처음 만나는 점(.) 이후 부분은 제외 => naver
#규칙3: 남은 글자 중 처음 세자리 + 글자 갯수 + 글자 내 'e' 갯수 + "!"로 구성
#출력 예시: 생성된 비밀번호: nav51!

url = "http://naver.com"
my_str = url.replace("http://", "")
#print(my_str)
my_str = my_str[:my_str.index(".")] #my_str[0:5]이면 0 ~ 4까지 출력
#print(my_str)
password = my_str[:3] + str(len(my_str)) + str(my_str.count("e")) + "!"
print("{0} 의 비밀번호는 {1}입니다.".format(url, password))
# Out:
# http://naver.com 의 비밀번호는 nav51!입니다.
